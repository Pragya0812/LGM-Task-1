# %% [markdown]
# <a href="https://colab.research.google.com/github/Pragya0812/LGM-Task-1/blob/main/ImageToPencilSketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task-1 IMAGE TO PENCIL SKETCH USING PYTHON

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img = cv2.imread("dog.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=604x402 at 0x7F8C50A6A890>

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=604x402 at 0x7F8C4059F5D0>

# %%
img_invert = cv2.bitwise_not(img_gray)

# %%
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=604x402 at 0x7F8C405BCD90>

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=604x402 at 0x7F8C4055EA90>

# %%
def dodgeV2(x, y):
  return cv2.divide(x, 255 - y, scale=256)

# %%
final_img = dodgeV2(img_gray, img_smoothing)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=604x402 at 0x7F8C405A3ED0>
